# %% [markdown]
# # ✅ NumPy Basics & Slicing:
#
# Difference between np.array([1, 2, 3, 4, 5]) vs {1, 2, 3, 4, 5}
#
# Explanation of twod_arr[0:2, 1:3] and twod_arr[0, 0:1:2]
#
# Explain twod_arr[0, ::2]
#
# Why twod_arr[0,1::2] gives [2], not [3]
#
# Explain twod_arr[0, 0:2:2]
#
# # ✅ Higher-Dimensional Arrays & Shapes:
#
# Create and slice np.array with ndmin=5
#
# Use of np.nditer() with slicing like arr2[:, ::2] and arr2[::2]
#
# Explain np.stack() and use of axis
#
# Shape explanation for [[[[1 2],[3 4]]], [[[5 6],[7 8]]]] → (2, 1, 2, 2)
#
# # ✅ Searching & Indexing:
#
# How np.searchsorted() works with side='right' and default
#
# Is there a human way to understand/visualize high-dimensional arrays?
#
# Example for 4D array with shape (1, 2, 3, 4)
#
# Example for shape (2, 2, 1, 2)
#
# Example for shape (3, 2, 2, 2)
#
# Example for shape (3, 2, 3, 2)
#
# 5D array example: (3, 2, 2, 2, 1)
#
# 5D array example: (4, 3, 3, 2, 2)
#
# 5D array example: (2, 2, 3, 4, 1)
#
# # ✅ Normalization, Vectorization & Aggregation:
#
# Normalize a NumPy array to [0, 1]
#
# Purpose and use cases of np.vectorize()
#
# # ✅ Broadcasting, Mean & Axes:
#
# Difference between arr[:] = np.mean(arr, axis=1, keepdims=True) vs np.mean(arr)
#
# Mean over 3D arrays with different axes (0, 1, 2)
#
# Clarifying mean calculations (e.g., axis=0 meaning)
#
# Confused about why mean didn't update array correctly — expecting [1,1] etc.
#
# np.bincount() explanation
#
# Use of np.pad()
#
# Difference between np.linspace and np.arange
#
# # ✅ Copying & Views:
#
# Difference between np.array(), np.asarray(), and is identity check
#
# NumPy broadcasting rules (valid or invalid)
#
# More examples of valid/invalid broadcasting
#
# Broadcasting example: adding (2,2,3) and (3,)
#
# # ✅ Copy Types:
#
# Difference between deep copy and shallow copy
#
# Is .view() a shallow copy?
#
# Behavior of .copy() with copy=True
#
# # ✅ Conditional Indexing:
#
# Why this doesn't work: arr[np.where(arr > 3, 10, 20)]
#
# # ✅ Axes & Aggregation:
#
# In NumPy, is axis=0 column-wise or row-wise?
#
# # ✅ Randomization:
#
# Why does print(np.random.shuffle(arr)) return None?
#
# Difference between np.random.shuffle() and np.random.permutation()
