# %%
import pandas as pd
import numpy as np

# %%
iris = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', header=None, names=['sepal length','sepal width','petal length','petal width','class'])
iris
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris_grouped = iris.groupby('class')
iris_grouped.mean()
# Out:
#                  sepal length  sepal width  petal length  petal width
# class
# Iris-setosa             5.006        3.418         1.464        0.244
# Iris-versicolor         5.936        2.770         4.260        1.326
# Iris-virginica          6.588        2.974         5.552        2.026

# %%
iris_grouped.median()
# Out:
#                  sepal length  sepal width  petal length  petal width
# class
# Iris-setosa               5.0          3.4          1.50          0.2
# Iris-versicolor           5.9          2.8          4.35          1.3
# Iris-virginica            6.5          3.0          5.55          2.0

# %%
iris_grouped.std()
# Out:
#                  sepal length  sepal width  petal length  petal width
# class
# Iris-setosa          0.352490     0.381024      0.173511     0.107210
# Iris-versicolor      0.516171     0.313798      0.469911     0.197753
# Iris-virginica       0.635880     0.322497      0.551895     0.274650

# %%
iris_grouped.var()
# Out:
#                  sepal length  sepal width  petal length  petal width
# class
# Iris-setosa          0.124249     0.145180      0.030106     0.011494
# Iris-versicolor      0.266433     0.098469      0.220816     0.039106
# Iris-virginica       0.404343     0.104004      0.304588     0.075433

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.rcParams["figure.figsize"] = (7,7)
iris.plot(x='class',y='sepal length',kind='bar',color='green', width=0.5)
plt.show()

# %%
iris_grouped.skew()
# Out:
#                  sepal length  sepal width  petal length  petal width
# class
# Iris-setosa          0.120087     0.107053      0.071846     1.197243
# Iris-versicolor      0.105378    -0.362845     -0.606508    -0.031180
# Iris-virginica       0.118015     0.365949      0.549445    -0.129477

# %%
x = np.linspace(0,1,10)
y = np.random.rand(10)
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
plt.plot(x,y,color='green', linestyle='--', marker='o')

# %%
a = np.linspace(-np.pi, np.pi, 200, endpoint=True)
cosine, sine = np.cos(a), np.sin(a)
plt.plot(a, cosine, a, sine)
plt.figure(figsize=(10,6))
plt.plot(a, cosine, linestyle='dashed')     # plotting cosine function, red dashed line
plt.plot(a, sine, linestyle='dotted')       # plotting sine function, blue dotted line

# %%
plt.plot(a, cosine, label = 'cosine')                 # adding label parameter
plt.plot(a, sine, label = 'sine', color = 'green')    # adding the color parameter and label

plt.xlabel('Angle (radians)')
plt.ylabel('Amplitude')
plt.title('Cosine and Sine')
plt.legend()

# %%
plt.plot(a, cosine, label = 'cosine')                 # adding label parameter
plt.plot(a, sine, label = 'sine', color = 'green')    # adding the color parameter and label

plt.xlabel('Angle (radians)')
plt.ylabel('Amplitude')
plt.title('Cosine and Sine')
plt.legend(loc='upper left')

# %%
plt.plot(a, cosine, label = 'cos(a)')                 # adding label parameter
plt.plot(a, sine, label = 'sin(a)', color = 'green')    # adding the color parameter and label

plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Cosine and Sine')
plt.legend(loc='upper left')
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
       [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

plt.show()

# %%
plt.savefig('cosine_sine.pdf')
